# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np

from pathlib import Path
from typing import List

# %%
data_path = Path(".") / "Fantasy-Premier-League" / "data"

# %%
seasons = sorted([
    p.name for p in data_path.iterdir()
    if p.is_dir() and p.name[0].isdigit()
])
print(seasons)
# Out:
# ['2016-17', '2017-18', '2018-19', '2019-20', '2020-21', '2021-22', '2022-23', '2023-24', '2024-25', '2025-26']

# %%
seasons = ['2021-22', '2022-23', '2023-24', '2024-25', '2025-26']

# %%
def data_import(season_list: List[str]) -> pd.DataFrame:
    gws = np.arange(1, 39)
    dfs = []
    content = Path(".")

    for season in season_list:
        for gw in gws:
            try:
                file_name = f"gw{gw}.csv"
                path = content / "Fantasy-Premier-League" / "data" / season / "gws" / file_name

                df = pd.read_csv(path, encoding='latin1')

                df['gw'] = gw
                df['season'] = season

                if not df.empty:
                    dfs.append(df)

            except Exception as e:
                print(e)
                pass

    if not dfs:
        return pd.DataFrame()

    return pd.concat(dfs, axis=0, ignore_index=True)

# %%
data = data_import(season_list=seasons)
# Out:
# [Errno 2] No such file or directory: 'Fantasy-Premier-League\\data\\2025-26\\gws\\gw25.csv'
# [Errno 2] No such file or directory: 'Fantasy-Premier-League\\data\\2025-26\\gws\\gw26.csv'
# [Errno 2] No such file or directory: 'Fantasy-Premier-League\\data\\2025-26\\gws\\gw27.csv'
# [Errno 2] No such file or directory: 'Fantasy-Premier-League\\data\\2025-26\\gws\\gw28.csv'
# [Errno 2] No such file or directory: 'Fantasy-Premier-League\\data\\2025-26\\gws\\gw29.csv'
# [Errno 2] No such file or directory: 'Fantasy-Premier-League\\data\\2025-26\\gws\\gw30.csv'
# [Errno 2] No such file or directory: 'Fantasy-Premier-League\\data\\2025-26\\gws\\gw31.csv'
# [Errno 2] No such file or directory: 'Fantasy-Premier-League\\data\\2025-26\\gws\\gw32.csv'
# [Errno 2] No such file or directory: 'Fantasy-Premier-League\\data\\2025-26\\gws\\gw33.csv'
# [Errno 2] No such file or directory: 'Fantasy-Premier-League\\data\\2025-26\\gws\\gw34.csv'
# [Errno 2] No such file or directory: 'Fantasy-Premier-League\\data\\2025-26\\gws\\gw35.csv'
# [Errno 2] No such file or directory: 'Fantasy-Premier-League\\data\\2025-26\\gws\\gw36.csv'
# [Errno 2] No such file or directory: 'Fantasy-Premier-League\\data\\2025-26\\gws\\gw37.csv'
# [Errno 2] No such file or directory: 'Fantasy-Premier-League\\data\\2025-26\\gws\\gw38.csv'

# %%
data.head()
# Out:
#                             name position         team   xP  assists  bonus  \
# 0                    Eric Bailly      DEF      Man Utd  0.0        0      0
# 1                   Keinan Davis      FWD  Aston Villa  0.4        0      0
# 2         Ayotomiwa Dele-Bashiru      MID      Watford  0.0        0      0
# 3              James Ward-Prowse      MID  Southampton  2.3        0      0
# 4  Bruno Miguel Borges Fernandes      MID      Man Utd  4.4        0      3
#
#    bps  clean_sheets  creativity  element  fixture  goals_conceded  \
# 0    0             0         0.0      286        6               0
# 1    0             0         0.0       49        8               0
# 2    0             0         0.0      394        8               0
# 3   20             0        30.5      341        4               3
# 4   61             0        35.9      277        6               1
#
#    goals_scored  ict_index  influence          kickoff_time  minutes  \
# 0             0        0.0        0.0  2021-08-14T11:30:00Z        0
# 1             0        0.0        0.0  2021-08-14T14:00:00Z        0
# 2             0        0.0        0.0  2021-08-14T14:00:00Z        0
# 3             0        5.2       21.6  2021-08-14T14:00:00Z       90
# 4             3       20.1      106.2  2021-08-14T11:30:00Z       90
#
#    opponent_team  own_goals  penalties_missed  penalties_saved  red_cards  \
# 0             10          0                 0                0          0
# 1             18          0                 0                0          0
# 2              2          0                 0                0          0
# 3              8          0                 0                0          0
# 4             10          0                 0                0          0
#
#    round  saves  selected  team_a_score  team_h_score  threat  total_points  \
# 0      1      0      9363             1             5     0.0             0
# 1      1      0    169789             2             3     0.0             0
# 2      1      0      4092             2             3     0.0             0
# 3      1      0    299682             1             3     0.0             2
# 4      1      0   3381004             1             5    59.0            20
#
#    transfers_balance  transfers_in  transfers_out  value  was_home  \
# 0                  0             0              0     50      True
# 1                  0             0              0     45     False
# 2                  0             0              0     45      True
# 3                  0             0              0     65     False
# 4                  0             0              0    120      True
#
#    yellow_cards  gw   season  expected_assists  expected_goal_involvements  \
# 0             0   1  2021-22               NaN                         NaN
# 1             0   1  2021-22               NaN                         NaN
# 2             0   1  2021-22               NaN                         NaN
# 3             0   1  2021-22               NaN                         NaN
# 4             0   1  2021-22               NaN                         NaN
#
#    expected_goals  expected_goals_conceded  starts modified  mng_clean_sheets  \
# 0             NaN                      NaN     NaN      NaN               NaN
# 1             NaN                      NaN     NaN      NaN               NaN
# 2             NaN                      NaN     NaN      NaN               NaN
# 3             NaN                      NaN     NaN      NaN               NaN
# 4             NaN                      NaN     NaN      NaN               NaN
#
#    mng_draw  mng_goals_scored  mng_loss  mng_underdog_draw  mng_underdog_win  \
# 0       NaN               NaN       NaN                NaN               NaN
# 1       NaN               NaN       NaN                NaN               NaN
# 2       NaN               NaN       NaN                NaN               NaN
# 3       NaN               NaN       NaN                NaN               NaN
# 4       NaN               NaN       NaN                NaN               NaN
#
#    mng_win  clearances_blocks_interceptions  defensive_contribution  \
# 0      NaN                              NaN                     NaN
# 1      NaN                              NaN                     NaN
# 2      NaN                              NaN                     NaN
# 3      NaN                              NaN                     NaN
# 4      NaN                              NaN                     NaN
#
#    recoveries  tackles
# 0         NaN      NaN
# 1         NaN      NaN
# 2         NaN      NaN
# 3         NaN      NaN
# 4         NaN      NaN

# %%
def dtypes_conv(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()

    if 'kickoff_time' in df.columns:
        df['kickoff_time'] = pd.to_datetime(df['kickoff_time'], format='mixed', dayfirst=False)

    str_cols = df.select_dtypes(include=['object', 'string']).columns.difference(['kickoff_time'])
    df[str_cols] = df[str_cols].astype("string")

    numeric_cols = df.select_dtypes(exclude=['string', 'datetime64[ns]', 'datetimetz']).columns
    df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

    return df

# %%
def sort_data(df:pd.DataFrame)->pd.DataFrame:
  return df.sort_values(by=["element", "kickoff_time", "gw", "season"])

# %%
data = dtypes_conv(df=data)
data = sort_data(df=data)

# %%
data.head()
# Out:
#             name position     team   xP  assists  bonus  bps  clean_sheets  \
# 500   Bernd Leno       GK  Arsenal  3.6        0      0   11             0
# 1064  Bernd Leno       GK  Arsenal  1.5        0      0   17             0
# 1641  Bernd Leno       GK  Arsenal  0.8        0      0   20             0
# 2239  Bernd Leno       GK  Arsenal  2.0        0      0    0             0
# 2845  Bernd Leno       GK  Arsenal  1.8        0      0    0             0
#
#       creativity  element  fixture  goals_conceded  goals_scored  ict_index  \
# 500          0.0        1        1               2             0        1.2
# 1064         0.0        1       18               2             0        2.4
# 1641         0.0        1       24               5             0        4.3
# 2239         0.0        1       31               0             0        0.0
# 2845         0.0        1       43               0             0        0.0
#
#       influence              kickoff_time  minutes  opponent_team  own_goals  \
# 500        11.8 2021-08-13 19:00:00+00:00       90              3          0
# 1064       24.2 2021-08-22 15:30:00+00:00       90              6          0
# 1641       43.0 2021-08-28 11:30:00+00:00       90             12          0
# 2239        0.0 2021-09-11 14:00:00+00:00        0             15          0
# 2845        0.0 2021-09-18 14:00:00+00:00        0              5          0
#
#       penalties_missed  penalties_saved  red_cards  round  saves  selected  \
# 500                  0                0          0      1      1    153122
# 1064                 0                0          0      2      3    144885
# 1641                 0                0          0      3      5    136757
# 2239                 0                0          0      4      0    153130
# 2845                 0                0          0      5      0    129851
#
#       team_a_score  team_h_score  threat  total_points  transfers_balance  \
# 500              0             2     0.0             1                  0
# 1064             2             0     0.0             2             -25816
# 1641             0             5     0.0             1             -14559
# 2239             0             1     0.0             0               6564
# 2845             1             0     0.0             0             -23847
#
#       transfers_in  transfers_out  value  was_home  yellow_cards  gw   season  \
# 500              0              0     50     False             0   1  2021-22
# 1064          2627          28443     50      True             0   2  2021-22
# 1641          5164          19723     49     False             0   3  2021-22
# 2239         35360          28796     49      True             0   4  2021-22
# 2845          4822          28669     49     False             0   5  2021-22
#
#       expected_assists  expected_goal_involvements  expected_goals  \
# 500                NaN                         NaN             NaN
# 1064               NaN                         NaN             NaN
# 1641               NaN                         NaN             NaN
# 2239               NaN                         NaN             NaN
# 2845               NaN                         NaN             NaN
#
#       expected_goals_conceded  starts modified  mng_clean_sheets  mng_draw  \
# 500                       NaN     NaN     <NA>               NaN       NaN
# 1064                      NaN     NaN     <NA>               NaN       NaN
# 1641                      NaN     NaN     <NA>               NaN       NaN
# 2239                      NaN     NaN     <NA>               NaN       NaN
# 2845                      NaN     NaN     <NA>               NaN       NaN
#
#       mng_goals_scored  mng_loss  mng_underdog_draw  mng_underdog_win  \
# 500                NaN       NaN                NaN               NaN
# 1064               NaN       NaN                NaN               NaN
# 1641               NaN       NaN                NaN               NaN
# 2239               NaN       NaN                NaN               NaN
# 2845               NaN       NaN                NaN               NaN
#
#       mng_win  clearances_blocks_interceptions  defensive_contribution  \
# 500       NaN                              NaN                     NaN
# 1064      NaN                              NaN                     NaN
# 1641      NaN                              NaN                     NaN
# 2239      NaN                              NaN                     NaN
# 2845      NaN                              NaN                     NaN
#
#       recoveries  tackles
# 500          NaN      NaN
# 1064         NaN      NaN
# 1641         NaN      NaN
# 2239         NaN      NaN
# 2845         NaN      NaN

# %%
data.shape
# Out:
# (127465, 54)
