# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np


from pathlib import Path
from typing import List

# %%
data_path = Path("..") / "Fantasy-Premier-League" / "data"

# %%
seasons = sorted([
    p.name for p in data_path.iterdir()
    if p.is_dir() and p.name[0].isdigit()
])
print(seasons)
# Out:
# ['2016-17', '2017-18', '2018-19', '2019-20', '2020-21', '2021-22', '2022-23', '2023-24', '2024-25', '2025-26']

# %%
seasons = ['2021-22', '2022-23', '2023-24', '2024-25', '2025-26']

# %%
def data_import(season_list: List[str]) -> pd.DataFrame:
    gws = np.arange(1, 39)
    dfs = []
    content = Path("..")

    for season in season_list:
        for gw in gws:
            try:
                file_name = f"gw{gw}.csv"
                path = content / "Fantasy-Premier-League" / "data" / season / "gws" / file_name

                df = pd.read_csv(path, encoding='utf-8')
                df['season'] = season

                if not df.empty:
                    dfs.append(df)

            except Exception as e:
                print(e)
                pass

    if not dfs:
        return pd.DataFrame()

    return pd.concat(dfs, axis=0, ignore_index=True)

# %%
data = data_import(season_list=seasons)
# Out:
# [Errno 2] No such file or directory: '..\\Fantasy-Premier-League\\data\\2025-26\\gws\\gw25.csv'
# [Errno 2] No such file or directory: '..\\Fantasy-Premier-League\\data\\2025-26\\gws\\gw26.csv'
# [Errno 2] No such file or directory: '..\\Fantasy-Premier-League\\data\\2025-26\\gws\\gw27.csv'
# [Errno 2] No such file or directory: '..\\Fantasy-Premier-League\\data\\2025-26\\gws\\gw28.csv'
# [Errno 2] No such file or directory: '..\\Fantasy-Premier-League\\data\\2025-26\\gws\\gw29.csv'
# [Errno 2] No such file or directory: '..\\Fantasy-Premier-League\\data\\2025-26\\gws\\gw30.csv'
# [Errno 2] No such file or directory: '..\\Fantasy-Premier-League\\data\\2025-26\\gws\\gw31.csv'
# [Errno 2] No such file or directory: '..\\Fantasy-Premier-League\\data\\2025-26\\gws\\gw32.csv'
# [Errno 2] No such file or directory: '..\\Fantasy-Premier-League\\data\\2025-26\\gws\\gw33.csv'
# [Errno 2] No such file or directory: '..\\Fantasy-Premier-League\\data\\2025-26\\gws\\gw34.csv'
# [Errno 2] No such file or directory: '..\\Fantasy-Premier-League\\data\\2025-26\\gws\\gw35.csv'
# [Errno 2] No such file or directory: '..\\Fantasy-Premier-League\\data\\2025-26\\gws\\gw36.csv'
# [Errno 2] No such file or directory: '..\\Fantasy-Premier-League\\data\\2025-26\\gws\\gw37.csv'
# [Errno 2] No such file or directory: '..\\Fantasy-Premier-League\\data\\2025-26\\gws\\gw38.csv'

# %%
data.head()
# Out:
#                             name position         team   xP  assists  bonus  \
# 0                    Eric Bailly      DEF      Man Utd  0.0        0      0
# 1                   Keinan Davis      FWD  Aston Villa  0.4        0      0
# 2         Ayotomiwa Dele-Bashiru      MID      Watford  0.0        0      0
# 3              James Ward-Prowse      MID  Southampton  2.3        0      0
# 4  Bruno Miguel Borges Fernandes      MID      Man Utd  4.4        0      3
#
#    bps  clean_sheets  creativity  element  fixture  goals_conceded  \
# 0    0             0         0.0      286        6               0
# 1    0             0         0.0       49        8               0
# 2    0             0         0.0      394        8               0
# 3   20             0        30.5      341        4               3
# 4   61             0        35.9      277        6               1
#
#    goals_scored  ict_index  influence          kickoff_time  minutes  \
# 0             0        0.0        0.0  2021-08-14T11:30:00Z        0
# 1             0        0.0        0.0  2021-08-14T14:00:00Z        0
# 2             0        0.0        0.0  2021-08-14T14:00:00Z        0
# 3             0        5.2       21.6  2021-08-14T14:00:00Z       90
# 4             3       20.1      106.2  2021-08-14T11:30:00Z       90
#
#    opponent_team  own_goals  penalties_missed  penalties_saved  red_cards  \
# 0             10          0                 0                0          0
# 1             18          0                 0                0          0
# 2              2          0                 0                0          0
# 3              8          0                 0                0          0
# 4             10          0                 0                0          0
#
#    round  saves  selected  team_a_score  team_h_score  threat  total_points  \
# 0      1      0      9363             1             5     0.0             0
# 1      1      0    169789             2             3     0.0             0
# 2      1      0      4092             2             3     0.0             0
# 3      1      0    299682             1             3     0.0             2
# 4      1      0   3381004             1             5    59.0            20
#
#    transfers_balance  transfers_in  transfers_out  value  was_home  \
# 0                  0             0              0     50      True
# 1                  0             0              0     45     False
# 2                  0             0              0     45      True
# 3                  0             0              0     65     False
# 4                  0             0              0    120      True
#
#    yellow_cards   season  expected_assists  expected_goal_involvements  \
# 0             0  2021-22               NaN                         NaN
# 1             0  2021-22               NaN                         NaN
# 2             0  2021-22               NaN                         NaN
# 3             0  2021-22               NaN                         NaN
# 4             0  2021-22               NaN                         NaN
#
#    expected_goals  expected_goals_conceded  starts modified  mng_clean_sheets  \
# 0             NaN                      NaN     NaN      NaN               NaN
# 1             NaN                      NaN     NaN      NaN               NaN
# 2             NaN                      NaN     NaN      NaN               NaN
# 3             NaN                      NaN     NaN      NaN               NaN
# 4             NaN                      NaN     NaN      NaN               NaN
#
#    mng_draw  mng_goals_scored  mng_loss  mng_underdog_draw  mng_underdog_win  \
# 0       NaN               NaN       NaN                NaN               NaN
# 1       NaN               NaN       NaN                NaN               NaN
# 2       NaN               NaN       NaN                NaN               NaN
# 3       NaN               NaN       NaN                NaN               NaN
# 4       NaN               NaN       NaN                NaN               NaN
#
#    mng_win  clearances_blocks_interceptions  defensive_contribution  \
# 0      NaN                              NaN                     NaN
# 1      NaN                              NaN                     NaN
# 2      NaN                              NaN                     NaN
# 3      NaN                              NaN                     NaN
# 4      NaN                              NaN                     NaN
#
#    recoveries  tackles
# 0         NaN      NaN
# 1         NaN      NaN
# 2         NaN      NaN
# 3         NaN      NaN
# 4         NaN      NaN

# %%
def sort_data(df:pd.DataFrame)->pd.DataFrame:
  return df.sort_values(by=["name", "kickoff_time", "fixture", "season"])

# %%
data = sort_data(df=data)

# %%
data.head()
# Out:
#                    name position     team   xP  assists  bonus  bps  \
# 98924   Aaron Anselmino      DEF  Chelsea  1.8        0      0    0
# 99717   Aaron Anselmino      DEF  Chelsea  0.5        0      0    0
# 100500  Aaron Anselmino      DEF  Chelsea  1.0        0      0    0
# 101288  Aaron Anselmino      DEF  Chelsea  0.5        0      0    0
# 101946  Aaron Anselmino      DEF  Chelsea  0.0        0      0    0
#
#         clean_sheets  creativity  element  fixture  goals_conceded  \
# 98924              0         0.0      774      242               0
# 99717              0         0.0      774      252               0
# 100500             0         0.0      774      268               0
# 101288             0         0.0      774      273               0
# 101946             0         0.0      774      281               0
#
#         goals_scored  ict_index  influence          kickoff_time  minutes  \
# 98924              0        0.0        0.0  2025-02-14T20:00:00Z        0
# 99717              0        0.0        0.0  2025-02-22T17:30:00Z        0
# 100500             0        0.0        0.0  2025-02-25T20:15:00Z        0
# 101288             0        0.0        0.0  2025-03-09T14:00:00Z        0
# 101946             0        0.0        0.0  2025-03-16T13:30:00Z        0
#
#         opponent_team  own_goals  penalties_missed  penalties_saved  \
# 98924               5          0                 0                0
# 99717               2          0                 0                0
# 100500             17          0                 0                0
# 101288             11          0                 0                0
# 101946              1          0                 0                0
#
#         red_cards  round  saves  selected  team_a_score  team_h_score  threat  \
# 98924           0     25      0         0             0             3     0.0
# 99717           0     26      0       156             1             2     0.0
# 100500          0     27      0       236             0             4     0.0
# 101288          0     28      0       325             0             1     0.0
# 101946          0     29      0       436             0             1     0.0
#
#         total_points  transfers_balance  transfers_in  transfers_out  value  \
# 98924              0                  0             0              0     40
# 99717              0                 82            92             10     40
# 100500             0                 29            58             29     40
# 101288             0                 21            52             31     40
# 101946             0                  4            31             27     40
#
#         was_home  yellow_cards   season  expected_assists  \
# 98924      False             0  2024-25               0.0
# 99717      False             0  2024-25               0.0
# 100500      True             0  2024-25               0.0
# 101288      True             0  2024-25               0.0
# 101946     False             0  2024-25               0.0
#
#         expected_goal_involvements  expected_goals  expected_goals_conceded  \
# 98924                          0.0             0.0                      0.0
# 99717                          0.0             0.0                      0.0
# 100500                         0.0             0.0                      0.0
# 101288                         0.0             0.0                      0.0
# 101946                         0.0             0.0                      0.0
#
#         starts modified  mng_clean_sheets  mng_draw  mng_goals_scored  \
# 98924      0.0    False               0.0       0.0               0.0
# 99717      0.0    False               0.0       0.0               0.0
# 100500     0.0    False               0.0       0.0               0.0
# 101288     0.0    False               0.0       0.0               0.0
# 101946     0.0    False               0.0       0.0               0.0
#
#         mng_loss  mng_underdog_draw  mng_underdog_win  mng_win  \
# 98924        0.0                0.0               0.0      0.0
# 99717        0.0                0.0               0.0      0.0
# 100500       0.0                0.0               0.0      0.0
# 101288       0.0                0.0               0.0      0.0
# 101946       0.0                0.0               0.0      0.0
#
#         clearances_blocks_interceptions  defensive_contribution  recoveries  \
# 98924                               NaN                     NaN         NaN
# 99717                               NaN                     NaN         NaN
# 100500                              NaN                     NaN         NaN
# 101288                              NaN                     NaN         NaN
# 101946                              NaN                     NaN         NaN
#
#         tackles
# 98924       NaN
# 99717       NaN
# 100500      NaN
# 101288      NaN
# 101946      NaN

# %%
data.shape
# Out:
# (127465, 53)

# %%
filename = "FPL_data_untidy.csv"
data.to_csv(filename, index=False)
