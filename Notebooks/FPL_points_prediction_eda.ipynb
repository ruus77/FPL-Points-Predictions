# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "../Data/FPL_data_24_26_cleaned.csv"
data = pd.read_csv(path)

# %%
data.head()
# Out:
#       season status player    position         kickoff_time  gw  player_id  \
# 0  2025-2026      a   Raya  Goalkeeper  2025-08-17 15:30:00   1          1
# 1  2025-2026      a   Raya  Goalkeeper  2025-08-23 16:30:00   2          1
# 2  2025-2026      a   Raya  Goalkeeper  2025-08-31 15:30:00   3          1
# 3  2025-2026      a   Raya  Goalkeeper  2025-09-13 11:30:00   4          1
# 4  2025-2026      a   Raya  Goalkeeper  2025-09-21 15:30:00   5          1
#
#    minutes_played  goals  assists  ...  threat_rank_type  ict_index  \
# 0              90      0        0  ...              88.0        4.9
# 1              90      0        0  ...             345.0        6.2
# 2              90      0        0  ...             345.0        9.2
# 3              90      0        0  ...             345.0       10.5
# 4              90      0        0  ...             345.0       12.6
#
#    ict_index_rank  ict_index_rank_type  corners_and_indirect_freekicks_order  \
# ...

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(data[data.select_dtypes('number').corr().nlargest(20, 'y_points').index].corr(), annot=True, fmt=".2f", cmap="coolwarm")
# Out:
# <Axes: >
